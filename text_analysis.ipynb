# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninga001/AI-predictive-model/blob/main/text_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import nltk

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
text1="""Hello Mr. Smith, how are you doing today? The weather is great, and
city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""

# %%
tokenized_text=sent_tokenize(text1)
print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and \ncity is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %% [markdown]
# word Tokenization

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text1)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %% [markdown]
# frequency *distribution*

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
fdist.most_common(2)
[('is', 3), (',', 2)]
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
# Out:
# <FreqDist with 25 samples and 30 outcomes>

# %% [markdown]
# stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {"it's", 'its', 'shan', 'into', 'all', 'having', 'wasn', 'when', 'out', 'her', 'below', "aren't", 'this', 'how', 'i', 'mustn', "doesn't", 'ourselves', 'more', 'through', 'very', 'an', 'me', 'have', 'aren', 'these', 'such', 'after', "needn't", 'same', 'ma', "she's", 'or', 'so', 's', 'too', 'itself', 'the', "don't", 'other', "couldn't", 'off', 'ain', 'against', 'he', 'be', 'hadn', 'whom', 'ours', 'a', 'yours', 'nor', 'only', "weren't", 'about', 'weren', 'at', 'here', 'for', 'those', "haven't", 'were', 'it', 'will', 'above', "that'll", 'where', 'she', 'some', 'as', 'no', 'don', 'because', 'any', 'once', 'each', 'him', 'has', 'mightn', 'they', 'of', 'yourself', "wouldn't", 'there', 'doing', 'while', 'my', 'haven', 're', 'hers', 'but', 'his', 'again', "wasn't", 'between', 'our', 'am', 'to', 'shouldn', 'do', 'can', 'didn', 'won', 'both', 'own', 'that', 'with', 'is', 'doesn', 'on', 'then', 'being', 'now', 'hasn', 'not', 'what', 'them', 'yourselves', 'himself', 'just', "won't", 'are', 'few',
# ...

# %% [markdown]
# Removing Stopwords

# %%
filtered_sent=[]
for w in tokenized_word:
 if w not in stop_words:
      filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']
# Filterd Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard']
